# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/aze/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/aze/darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 14751 (delta 0), reused 1 (delta 0), pack-reused 14748
# Receiving objects: 100% (14751/14751), 13.28 MiB | 6.16 MiB/s, done.
# Resolving deltas: 100% (10029/10029), done.
# Checking out files: 100% (2023/2023), done.

# %%
cd /content/drive/MyDrive/aze/darknet/
# Out:
# /content/drive/MyDrive/aze/darknet

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# !python '/content/drive/MyDrive/aze/aze/creating-files-data-and-name.py'

# %%
# !python '/content/drive/MyDrive/aze/aze/creating-train-and-test-txt-files.py'

# %%
# !chmod +x ./darknet

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
cd /content/drive/MyDrive/clean/darknet/
# Out:
# /content/drive/MyDrive/clean/darknet

# %%
cd ..
# Out:
# /content/drive/My Drive/aze

# %%
pwd
# Out:
# '/content/drive/My Drive/aze'

# %%
# !darknet/darknet detector train traffic_light/labelled_data.data darknet/cfg/yolov4_custom.cfg -dont_show

# %%
# !darknet/darknet detector train aze/labelled_data.data darknet/cfg/yolov4-custom.cfg backup/yolov4.conv.137 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.678315), count: 15, class_loss = 11.338776, iou_loss = 226.823303, total_loss = 238.162079
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.766289), count: 17, class_loss = 1.920346, iou_loss = 68.940598, total_loss = 70.860947
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.661208), count: 4, class_loss = 0.415041, iou_loss = 4.494721, total_loss = 4.909761
#  total_bbox = 1445112, rewritten_bbox = 0.154037 %
# Invalid SOS parameters for sequential JPEG
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.615779), count: 8, class_loss = 6.490019, iou_loss = 196.973190, total_loss = 203.463211
# ...
